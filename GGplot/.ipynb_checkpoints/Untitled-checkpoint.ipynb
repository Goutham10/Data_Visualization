# %%
pip install pydataset
# Out:
# Collecting pydataset
#   Downloading pydataset-0.2.0.tar.gz (15.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 23.1 MB/s eta 0:00:00m eta 0:00:010:01:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /home/vy/anaconda3/lib/python3.9/site-packages (from pydataset) (1.4.2)
# Requirement already satisfied: numpy>=1.18.5 in /home/vy/anaconda3/lib/python3.9/site-packages (from pandas->pydataset) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/vy/anaconda3/lib/python3.9/site-packages (from pandas->pydataset) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/vy/anaconda3/lib/python3.9/site-packages (from pandas->pydataset) (2021.3)
# Requirement already satisfied: six>=1.5 in /home/vy/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->pydataset) (1.16.0)
# Building wheels for collected packages: pydataset
#   Building wheel for pydataset (setup.py) ... done
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939430 sha256=10079b579d0d4c845fb45e8385b0faaf6f6e7a153b883580e37fcb888ec6f468
#   Stored in directory: /home/vy/.cache/pip/wheels/6b/86/a7/f71cb84c7bff804d83e293615a20c0531234397b796aee2645
# Successfully built pydataset
# Installing collected packages: pydataset
# Successfully installed pydataset-0.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotnine
from plotnine import ggplot, aes
import pandas as pd
ju
from plotnine.data import mtcars
from vega_datasets import data as vds
from pydataset import data as pyds

from mizani.formatters import comma_format
import ipywidgets
import warnings
warnings.filterwarnings('ignore')

# %%
plotnine.qplot(x = 'wt', 
               y ='mpg', 
               data = plotnine.data.mtcars, 
               color ='cyl')
# Out:
# <ggplot: (8782144150248)>
